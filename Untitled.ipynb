# %% [markdown]
# # Аналитическая записка
# # "Проверка гипотезы классификации проявления болезни ... на этапе исследования изображения клеток"
# ## 1. Постановка задачи
# ### 1.1 Общее описание проблемы
# ### 1.2. Постановка бизнес-задачи
# ### 1.3. Гипотеза
# ### 1.4. Критерии приемки и требования к точности модели
# Примечания:
#
# Аналитическая записка содержит и аналитические выводы и технические детали (которые можно пропустить, если нет цели погрузиться в детали)
# Для экономии времени можно перейти сразу к разделу 4 "Выводы и рекомендации" в конце документа.
# ## 2.Результаты анализа исходных данных
# ### 2.1. Описание формата и состава исходных данных

# %%
#Импорт необходимых модулей
import torch
